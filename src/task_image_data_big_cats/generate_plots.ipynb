# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from visualization_utils import plot_compare_scores

# %% [markdown]
# ## 1) SIFT + BOVW features

# %%
dir_sift_data = "sift_features/"

# %%
str_sift = "[SIFT + BOVW features]"

# %% [markdown]
# ## 1.1) KNN - Accuracy score comparison plots

# %%
file_cv_knn = os.path.join(dir_sift_data, "image_classification_gs_cv_knn.csv")
file_test_knn = os.path.join(dir_sift_data, "image_classification_test_knn.csv")

df_cv_knn = pd.read_csv(file_cv_knn)
df_test_knn = pd.read_csv(file_test_knn)

df_cv_knn_std_scaler = df_cv_knn[df_cv_knn["preprocess"] == "std_scaler"]
df_cv_knn_tf_idf = df_cv_knn[df_cv_knn["preprocess"] == "tf_idf"]
df_test_knn_std_scaler = df_test_knn[df_test_knn["preprocess"] == "std_scaler"]
df_test_knn_tf_idf = df_test_knn[df_test_knn["preprocess"] == "tf_idf"]

# %%
plot_compare_scores(df_cv_knn_std_scaler.num_visual_words.to_numpy(), 
                    df_cv_knn_std_scaler.best_cv_score.to_numpy(),
                    df_cv_knn_tf_idf.best_cv_score.to_numpy(),
                    str_title="Comaprison of cross validation accuracy score for std_scaler vs tf_idf for KNN "+str_sift,
                    what_comparison="preprocess",
                    str_label_plot_1="best cross validation accuracy score - std_scaler",
                    str_label_plot_2="best cross validation accuracy score - tf_idf")
# Out:
# D:\code_repo\RUG\PR_AI_Assignment_2\src\task_image_data_big_cats\visualization_utils.py:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plot_compare_scores(df_test_knn_std_scaler.num_visual_words.to_numpy(), 
                    df_test_knn_std_scaler.test_acc.to_numpy(),
                    df_test_knn_tf_idf.test_acc.to_numpy(),
                    str_title="Comaprison of test accuracy score for std_scaler vs tf_idf for KNN "+str_sift,
                    what_comparison="preprocess",
                    str_label_plot_1="best test accuracy score - std_scaler",
                    str_label_plot_2="best test accuracy score - tf_idf")
# Out:
# D:\code_repo\RUG\PR_AI_Assignment_2\src\task_image_data_big_cats\visualization_utils.py:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plot_compare_scores(df_cv_knn_std_scaler.num_visual_words.to_numpy(), 
                    df_cv_knn_std_scaler.best_cv_score.to_numpy(),
                    df_test_knn_std_scaler.test_acc.to_numpy(),
                    str_title="Comaprison of cross validation vs test accuracy score with std_scaler for KNN "+str_sift)
# Out:
# D:\code_repo\RUG\PR_AI_Assignment_2\src\task_image_data_big_cats\visualization_utils.py:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plot_compare_scores(df_cv_knn_tf_idf.num_visual_words.to_numpy(), 
                    df_cv_knn_tf_idf.best_cv_score.to_numpy(),
                    df_test_knn_tf_idf.test_acc.to_numpy(),
                    str_title="Comaprison of cross validation vs test accuracy score with tf_idf for KNN "+str_sift)
# Out:
# D:\code_repo\RUG\PR_AI_Assignment_2\src\task_image_data_big_cats\visualization_utils.py:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## 1.2) SVC - Accuracy score comparison plots

# %%
file_cv_svc = os.path.join(dir_sift_data, "image_classification_gs_cv_svc.csv")
file_test_svc = os.path.join(dir_sift_data, "image_classification_test_svc.csv")

df_cv_svc = pd.read_csv(file_cv_svc)
df_test_svc = pd.read_csv(file_test_svc)

df_cv_svc_std_scaler = df_cv_svc[df_cv_svc["preprocess"] == "std_scaler"]
df_cv_svc_tf_idf = df_cv_svc[df_cv_svc["preprocess"] == "tf_idf"]
df_test_svc_std_scaler = df_test_svc[df_test_svc["preprocess"] == "std_scaler"]
df_test_svc_tf_idf = df_test_svc[df_test_svc["preprocess"] == "tf_idf"]

# %%
plot_compare_scores(df_cv_svc_std_scaler.num_visual_words.to_numpy(), 
                    df_cv_svc_std_scaler.best_cv_score.to_numpy(),
                    df_cv_svc_tf_idf.best_cv_score.to_numpy(),
                    str_title="Comaprison of cross validation accuracy score for std_scaler vs tf_idf for SVC "+str_sift,
                    what_comparison="preprocess",
                    str_label_plot_1="best cross validation accuracy score - std_scaler",
                    str_label_plot_2="best cross validation accuracy score - tf_idf")
# Out:
# D:\code_repo\RUG\PR_AI_Assignment_2\src\task_image_data_big_cats\visualization_utils.py:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plot_compare_scores(df_test_svc_std_scaler.num_visual_words.to_numpy(), 
                    df_test_svc_std_scaler.test_acc.to_numpy(),
                    df_test_svc_tf_idf.test_acc.to_numpy(),
                    str_title="Comaprison of test accuracy score for std_scaler vs tf_idf for SVC "+str_sift,
                    what_comparison="preprocess",
                    str_label_plot_1="best test accuracy score - std_scaler",
                    str_label_plot_2="best test accuracy score - tf_idf")
# Out:
# D:\code_repo\RUG\PR_AI_Assignment_2\src\task_image_data_big_cats\visualization_utils.py:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plot_compare_scores(df_cv_svc_std_scaler.num_visual_words.to_numpy(), 
                    df_cv_svc_std_scaler.best_cv_score.to_numpy(),
                    df_test_svc_std_scaler.test_acc.to_numpy(),
                    str_title="Comaprison of cross validation vs test accuracy score with std_scaler for SVC "+str_sift)
# Out:
# D:\code_repo\RUG\PR_AI_Assignment_2\src\task_image_data_big_cats\visualization_utils.py:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plot_compare_scores(df_cv_svc_tf_idf.num_visual_words.to_numpy(), 
                    df_cv_svc_tf_idf.best_cv_score.to_numpy(),
                    df_test_svc_tf_idf.test_acc.to_numpy(),
                    str_title="Comaprison of cross validation vs test accuracy score with tf_idf for SVC "+str_sift)
# Out:
# D:\code_repo\RUG\PR_AI_Assignment_2\src\task_image_data_big_cats\visualization_utils.py:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## 1.3) AdaBoost - Accuracy score comparison plots

# %%
file_cv_adaboost = os.path.join(dir_sift_data, "image_classification_gs_cv_adaboost.csv")
file_test_adaboost = os.path.join(dir_sift_data, "image_classification_test_adaboost.csv")

df_cv_adaboost = pd.read_csv(file_cv_adaboost)
df_test_adaboost = pd.read_csv(file_test_adaboost)

df_cv_adaboost_std_scaler = df_cv_adaboost[df_cv_adaboost["preprocess"] == "std_scaler"]
df_cv_adaboost_tf_idf = df_cv_adaboost[df_cv_adaboost["preprocess"] == "tf_idf"]
df_test_adaboost_std_scaler = df_test_adaboost[df_test_adaboost["preprocess"] == "std_scaler"]
df_test_adaboost_tf_idf = df_test_adaboost[df_test_adaboost["preprocess"] == "tf_idf"]

# %%
plot_compare_scores(df_cv_adaboost_std_scaler.num_visual_words.to_numpy(), 
                    df_cv_adaboost_std_scaler.best_cv_score.to_numpy(),
                    df_cv_adaboost_tf_idf.best_cv_score.to_numpy(),
                    str_title="Comaprison of cross validation accuracy score for std_scaler vs tf_idf for AdaBoost "+str_sift,
                    what_comparison="preprocess",
                    str_label_plot_1="best cross validation accuracy score - std_scaler",
                    str_label_plot_2="best cross validation accuracy score - tf_idf")
# Out:
# D:\code_repo\RUG\PR_AI_Assignment_2\src\task_image_data_big_cats\visualization_utils.py:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plot_compare_scores(df_test_adaboost_std_scaler.num_visual_words.to_numpy(), 
                    df_test_adaboost_std_scaler.test_acc.to_numpy(),
                    df_test_adaboost_tf_idf.test_acc.to_numpy(),
                    str_title="Comaprison of test accuracy score for std_scaler vs tf_idf for AdaBoost "+str_sift,
                    what_comparison="preprocess",
                    str_label_plot_1="best test accuracy score - std_scaler",
                    str_label_plot_2="best test accuracy score - tf_idf")
# Out:
# D:\code_repo\RUG\PR_AI_Assignment_2\src\task_image_data_big_cats\visualization_utils.py:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plot_compare_scores(df_cv_adaboost_std_scaler.num_visual_words.to_numpy(), 
                    df_cv_adaboost_std_scaler.best_cv_score.to_numpy(),
                    df_test_adaboost_std_scaler.test_acc.to_numpy(),
                    str_title="Comaprison of cross validation vs test accuracy score with std_scaler for AdaBoost "+str_sift)
# Out:
# D:\code_repo\RUG\PR_AI_Assignment_2\src\task_image_data_big_cats\visualization_utils.py:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plot_compare_scores(df_cv_adaboost_tf_idf.num_visual_words.to_numpy(), 
                    df_cv_adaboost_tf_idf.best_cv_score.to_numpy(),
                    df_test_adaboost_tf_idf.test_acc.to_numpy(),
                    str_title="Comaprison of cross validation vs test accuracy score with tf_idf for AdaBoost "+str_sift)
# Out:
# D:\code_repo\RUG\PR_AI_Assignment_2\src\task_image_data_big_cats\visualization_utils.py:25: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
